# %%
import json 
from datetime import datetime
import typing as ty

import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Данные матчей для профф игроков за период 1.04.2021 - 1.11.2021

# %%
sql_attrs = """player_matches.match_id,
player_matches.account_id,
player_matches.player_slot,
player_matches.hero_id,
player_matches.kills,
player_matches.deaths, 
player_matches.assists,
player_matches.leaver_status, 
player_matches.gold, 
player_matches.last_hits,
player_matches.denies,
player_matches.gold_per_min,
player_matches.xp_per_min,
player_matches.gold_spent,
player_matches.hero_damage,
player_matches.tower_damage,
player_matches.hero_healing,
player_matches.level,
player_matches.creeps_stacked,
player_matches.obs_placed,
player_matches.sen_placed,
player_matches.camps_stacked,
player_matches.rune_pickups,
player_matches.lane,
player_matches.lane_role,
player_matches.is_roaming,
player_matches.firstblood_claimed,
player_matches.teamfight_participation,
player_matches.towers_killed,
player_matches.roshans_killed,
player_matches.party_size,
player_matches.net_worth"""

# %%
sql_attrs = ', '.join([attr.strip() for attr in sql_attrs.split(',')])

# %%
sql_attrs
# Out:
# 'player_matches.match_id, player_matches.account_id, player_matches.player_slot, player_matches.hero_id, player_matches.kills, player_matches.deaths, player_matches.assists, player_matches.leaver_status, player_matches.gold, player_matches.last_hits, player_matches.denies, player_matches.gold_per_min, player_matches.xp_per_min, player_matches.gold_spent, player_matches.hero_damage, player_matches.tower_damage, player_matches.hero_healing, player_matches.level, player_matches.creeps_stacked, player_matches.obs_placed, player_matches.sen_placed, player_matches.camps_stacked, player_matches.rune_pickups, player_matches.lane, player_matches.lane_role, player_matches.is_roaming, player_matches.firstblood_claimed, player_matches.teamfight_participation, player_matches.towers_killed, player_matches.roshans_killed, player_matches.party_size, player_matches.net_worth'

# %% [markdown]
# <h1>Data for pro players

# %% [markdown]
# <h3>TODO: request asynchronously

# %%
def get_players_stats_per_match(player_ids: ty.List[int], matches=100):
    shared_matches_list = []
    responses_status = []
    with open('player_stats.json', 'w', encoding='utf-8') as writer:
        for player_id in player_ids:
            player_recent_matches = requests.get(
                f"https://api.opendota.com/api/explorer?sql=SELECT {sql_attrs} FROM player_matches JOIN matches ON matches.match_id = player_matches.match_id WHERE player_matches.account_id = {player_id} AND matches.start_time >= extract(epoch from timestamp '2021-04-01T21:00:00.000Z') AND matches.start_time <= extract(epoch from timestamp '2021-11-01T21:00:00.000Z') AND player_matches.match_id IS NOT NULL ORDER BY matches.start_time LIMIT {matches}"
            )
            player_matches_dict = {player_id: player_recent_matches.json()}
            shared_matches_list.append(player_matches_dict)
            responses_status.append(player_recent_matches.status_code)
    
        if all([status_code == 200 for status_code in responses_status]):
            dict_to_save = json.dumps(shared_matches_list)
            writer.write(dict_to_save)
        else:
            print('Something went wrong, status code is: ', response.status_code)

# %% [markdown]
# <h3>Тестовая выборка игроков

# %%
players_ids_list = [302214028, 113331514, 321580662]

# %%
get_players_stats_per_match(players_ids_list)

# %%
with open('player_stats.json', 'r', encoding='utf-8') as file:
    players_matches = json.loads(file.read())

# %%
[match['match_id'] for match in players_matches[0]['302214028']['rows']][:10]
# Out:
# [5940129114,
#  5940316763,
#  5941689002,
#  5941839115,
#  5942003094,
#  5942402971,
#  5942484798,
#  5948347704,
#  5948486847,
#  5952853218]

# %%
[match['match_id'] for match in players_matches[2]['321580662']['rows']][:10]
# Out:
# [5940129114,
#  5940316763,
#  5941689002,
#  5941839115,
#  5942003094,
#  5942402971,
#  5942484798,
#  5948347704,
#  5948486847,
#  5952853218]

# %% [markdown]
# <h1>Data for simple hard workers

# %%
template = 'https://api.opendota.com/api'

# %%
resp = requests.get(f'{template}/playersByRank')
resp
# Out:
# <Response [200]>

# %%
resp.json()[0]
# Out:
# {'account_id': 268590680, 'rating': 80, 'fh_unavailable': False}

# %%
players = requests.get(f'{template}/players/{268590680}')
players
# Out:
# <Response [200]>

# %%
players.json()
# Out:
# {'tracked_until': None,
#  'profile': {'account_id': 268590680,
#   'personaname': '....',
#   'name': None,
#   'plus': False,
#   'cheese': 0,
#   'steamid': '76561198228856408',
#   'avatar': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fc/fcba662217dbe27de744fa30ddc4fe62ed83b28a.jpg',
#   'avatarmedium': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fc/fcba662217dbe27de744fa30ddc4fe62ed83b28a_medium.jpg',
#   'avatarfull': 'https://steamcdn-a.akamaihd.net/steamcommunity/public/images/avatars/fc/fcba662217dbe27de744fa30ddc4fe62ed83b28a_full.jpg',
#   'profileurl': 'https://steamcommunity.com/profiles/76561198228856408/',
#   'last_login': '2019-10-12T04:46:46.150Z',
#   'loccountrycode': None,
#   'is_contributor': False},
#  'solo_competitive_rank': 4185,
#  'rank_tier': 80,
#  'mmr_estimate': {'estimate': 4347},
#  'leaderboard_rank': 1295,
#  'competitive_rank': 3829}

# %% [markdown]
# <h2>Берем игроков, которые участвовали в самых последних матчах, в которых был известен средний рейтинг среди игроков

# %% [markdown]
# <h3>!!!Не запускать!!!

# %%
public_matches = requests.get(f'{template}/publicMatches')
if public_matches.status_code == 200:
    with open(f"public_matches_{datetime.now().strftime('%Y-%m-%d')}.json", 'w', encoding='utf-8') as writer:
        writer.write(public_matches.text)
else:
    print(f"Status code: {public_matches.status_code}")

# %%
with open('public_matches_2021-11-19.json', 'r') as json_read:
    public_matches = json.loads(json_read.read())
public_matches[1]
# Out:
# {'match_id': 6281528004,
#  'match_seq_num': 5250966828,
#  'radiant_win': True,
#  'start_time': 1637300703,
#  'duration': 1355,
#  'avg_mmr': 2720,
#  'num_mmr': 1,
#  'lobby_type': 7,
#  'game_mode': 3,
#  'avg_rank_tier': 42,
#  'num_rank_tier': 8,
#  'cluster': 227,
#  'radiant_team': '34,16,54,11,20',
#  'dire_team': '120,12,61,74,68'}

# %%
public_matches = [match for match in public_matches if match['avg_mmr'] is not None]
print(f"Средний ммр: {np.mean([match['avg_mmr'] for match in public_matches])}")
# Out:
# Средний ммр: 2977.9857142857145

# %%
len(public_matches)
# Out:
# 70

# %% [markdown]
# <h2>Возьмем 10 матчей (100 игроков)

# %%
matches = public_matches[:10]

# %%
choosed_matches = []

# %%
matches[0]
# Out:
# {'match_id': 6281528311,
#  'match_seq_num': 5250963470,
#  'radiant_win': False,
#  'start_time': 1637300723,
#  'duration': 961,
#  'avg_mmr': 3598,
#  'num_mmr': 2,
#  'lobby_type': 7,
#  'game_mode': 22,
#  'avg_rank_tier': 65,
#  'num_rank_tier': 3,
#  'cluster': 251,
#  'radiant_team': '31,62,17,129,80',
#  'dire_team': '70,86,111,101,106'}

# %%
match = requests.get(f"{template}/matches/{matches[0]['match_id']}")
match.status_code
# Out:
# 200

# %%
players_ids = []
none_count = 0
list_of_matches = []
for match in matches:
    match = requests.get(f"{template}/matches/{match['match_id']}").json()
    list_of_matches.append(match)
    for player in match['players']:
        if player['account_id'] is not None:
            players_ids.append(player['account_id'])
        else:
            none_count += 1
print('Players with None account_id: ', none_count)
# Out:
# Players with None account_id:  49

# %%
len(players_ids)
# Out:
# 51

# %% [markdown]
# <h2>Составление словаря матчей для каждого из игроков (по 10 матчей на игрока)

# %%
players_matches_dict = {}
for player_id in players_ids:
    player_data = {}
    data_to_update = []
    
    player_recent_matches = requests.get(f'{template}/players/{player_id}/recentMatches').json()
    print(player_id, len(player_recent_matches))
    players_matches_dict.update({player_id: player_recent_matches})
# Out:
# 174064427 20
# 392188374 20
# 841766108 20
# 169994900 20
# 156698978 20
# 1009579281 20
# 143405256 20
# 904949233 20
# 433597293 20
# 444131292 20
# 136338447 20
# 1153396350 20
# 130733045 20
# 337769284 20
# 341047050 20
# 104630948 20
# 190191816 20
# 76709175 20
# 986082247 20
# 115329684 20
# 123654076 20
# 145000525 20
# 249520711 20
# 387633093 20
# 153908425 20
# 446737104 20
# 207983361 20
# 137092505 20
# 140291105 20
# 315157158 20
# 162421742 20
# 158847773 20
# 136186119 20
# 404004408 20
# 438103869 20
# 126077488 20
# 408064598 20
# 219573493 20
# 19075248 20
# 203019168 20
# 133098114 20
# 219740999 20
# 426240268 20
# 227603210 20
# 140740476 20
# 1197065565 20
# 213856257 20
# 157721965 20
# 308686709 20
# 121769131 20
# 198723859 20

# %% [markdown]
# <h2>Creating dict with average mmr for each match for each player

# %%
players_matches_dict[174064427][5]
# Out:
# {'match_id': 6271932148,
#  'player_slot': 128,
#  'radiant_win': True,
#  'duration': 2395,
#  'game_mode': 22,
#  'lobby_type': 7,
#  'hero_id': 121,
#  'start_time': 1636777295,
#  'version': None,
#  'kills': 3,
#  'deaths': 10,
#  'assists': 8,
#  'skill': 3,
#  'xp_per_min': 468,
#  'gold_per_min': 400,
#  'hero_damage': 19228,
#  'tower_damage': 589,
#  'hero_healing': 0,
#  'last_hits': 219,
#  'lane': None,
#  'lane_role': None,
#  'is_roaming': None,
#  'cluster': 251,
#  'leaver_status': 0,
#  'party_size': 5}

# %% [markdown]
# <h2>Тестовый игрок с ID = 174064427

# %%
matches_for_test_player = players_matches_dict[174064427]

# %%
player = requests.get(f'{template}/players/{174064427}')
player.status_code
# Out:
# 200

# %%
player.json()['mmr_estimate']['estimate']
# Out:
# 3476

# %%
player_id_test = 174064427
player_id_index = [player_id_test] * len(matches_for_test_player)
all_matches_df = pd.DataFrame()
columns_ = list(matches_for_test_player[0].keys())
columns_.append('player_mmr')
# columns_.append('average_match_mmr')

player_mmr = requests.get(f'{template}/players/{174064427}').json()['mmr_estimate']['estimate']
for match in matches_for_test_player:
    # calculation average mmr for each match
    # TODO refactor cause so many requests per minute (it's crashes)
    # average_match_mmr = get_average_match_mmr(match)
    
    values = list(match.values())
    values.append(player_mmr)
    # values.append(average_match_mmr)
    match_df = pd.DataFrame([values], columns=columns_, index=[player_id_test])
    all_matches_df = all_matches_df.append(match_df)
    print(f"Match {match['match_id']} has beed parsed")
# radiant_wint = all_matches_df['radiant_win'].astype(int)
# all_matches_df['radiant_win'] = radiant_wint
all_matches_df.fillna(0)
# Out:
# Match 6281547334 has beed parsed
# Match 6281528311 has beed parsed
# Match 6281499225 has beed parsed
# Match 6280039217 has beed parsed
# Match 6279998879 has beed parsed
# Match 6271932148 has beed parsed
# Match 6271885416 has beed parsed
# Match 6271851560 has beed parsed
# Match 6268802962 has beed parsed
# Match 6268543285 has beed parsed
# Match 6268509980 has beed parsed
# Match 6268481440 has beed parsed
# Match 6268445319 has beed parsed
# Match 6268354441 has beed parsed
# Match 6268273294 has beed parsed
# Match 6265639899 has beed parsed
# Match 6265613518 has beed parsed
# Match 6265575995 has beed parsed
# Match 6257149316 has beed parsed
# Match 6257119179 has beed parsed
#              match_id  player_slot  radiant_win  duration  game_mode  \
# 174064427  6281547334            4        False      2493         22
# 174064427  6281528311            1        False       961         22
# 174064427  6281499225            3        False      2013         22
# 174064427  6280039217            2        False      3453         22
# 174064427  6279998879            1         True      2323         22
# 174064427  6271932148          128         True      2395         22
# 174064427  6271885416            0         True      2958         22
# 174064427  6271851560          128         True      1972         22
# 174064427  6268802962          129         True      1496         22
# 174064427  6268543285            4         True      1982         22
# 174064427  6268509980            4         True      2530         22
# 174064427  6268481440          132        False      1682         22
# 174064427  6268445319            4         True      1898         22
# 174064427  6268354441            1        False      1977         22
# 174064427  6268273294            1         True      3083         22
# 174064427  6265639899          129         True      2864         22
# 174064427  6265613518          129        False      1710         22
# 174064427  6265575995          129        False      2688         22
# 174064427  6257149316          128         True      3514         22
# 174064427  6257119179            0         True      1961         22
#
#            lobby_type  hero_id  start_time  version  kills  ...  tower_damage  \
# 174064427           7       52  1637302296        0     13  ...          3310
# 174064427           7      129  1637300723        0      1  ...           965
# 174064427           7       10  1637298309        0      4  ...          2896
# 174064427           7      112  1637214839        0      5  ...           306
# 174064427           7       25  1637211477        0     10  ...          7661
# 174064427           7      121  1636777295        0      3  ...           589
# 174064427           7       25  1636774018        0     10  ...         16355
# 174064427           7       98  1636771591        0      1  ...           252
# 174064427           7       10  1636609056        0      1  ...           120
# 174064427           7      120  1636585614        0      4  ...           894
# 174064427           7      135  1636582748        0     12  ...          4307
# 174064427           7       52  1636580652        0      8  ...         10370
# 174064427           7       98  1636578281        0      8  ...          2339
# 174064427           7       97  1636573374        0      0  ...            32
# 174064427           7      129  1636569550        0      8  ...           634
# 174064427           7      129  1636432808        0      5  ...          3287
# 174064427           7      104  1636430733        0      5  ...          4031
# 174064427           7       97  1636427593        0      4  ...          1955
# 174064427           7       10  1636007887        0     13  ...          8676
# 174064427           7       10  1636005597        0     11  ...         15648
#
#            hero_healing  last_hits  lane  lane_role  is_roaming  cluster  \
# 174064427             0        332     0          0           0      251
# 174064427             0         80     0          0           0      251
# 174064427             0        309     0          0           0      251
# 174064427          1784        115     0          0           0      251
# 174064427           110        269     0          0           0      251
# 174064427             0        219     0          0           0      251
# 174064427             0        408     0          0           0      251
# 174064427             0        127     0          0           0      251
# 174064427             0        130     0          0           0      251
# 174064427             0        148     0          0           0      251
# 174064427          7673        402     0          0           0      251
# 174064427          4805        163     0          0           0      251
# 174064427             0        144     0          0           0      251
# 174064427             0        109     0          0           0      251
# 174064427             0        272     0          0           0      251
# 174064427             0        499     0          0           0      251
# 174064427          1950        137     0          0           0      251
# 174064427             0        234     0          0           0      251
# 174064427             0        668     0          0           0      251
# 174064427             0        325     0          0           0      251
#
#            leaver_status  party_size  player_mmr
# 174064427              0           2        3476
# 174064427              1           3        3476
# 174064427              0           3        3476
# 174064427              0           2        3476
# 174064427              0           1        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           2        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
# 174064427              0           5        3476
#
# [20 rows x 26 columns]

# %%
all_matches_df.columns
# Out:
# Index(['match_id', 'player_slot', 'radiant_win', 'duration', 'game_mode',
#        'lobby_type', 'hero_id', 'start_time', 'version', 'kills', 'deaths',
#        'assists', 'skill', 'xp_per_min', 'gold_per_min', 'hero_damage',
#        'tower_damage', 'hero_healing', 'last_hits', 'lane', 'lane_role',
#        'is_roaming', 'cluster', 'leaver_status', 'party_size'],
#       dtype='object')

# %% [markdown]
# <h2>Общий датафрейм со всеми игроками

# %%
def get_average_match_mmr(match_): 
    mmr_for_players = []
    if isinstance(match, requests.Response):
        match_ = match_.json()
    match_ = requests.get(f"{template}/matches/{match_['match_id']}").json()
    print(f"match_id: {match_.keys()}")
    if 'error' in match_.keys():
        return
    for match_player in match_['players']:
        if match_player['account_id'] is not None:
            player_data = requests.get(f"{template}/players/{match_player['account_id']}")
            if player_data.status_code == 200:
                if 'mmr_estimate' in player_data.json():
                    mmr_for_players.append(player_data.json()['mmr_estimate']['estimate'])
                else:
                    # print('mmr_estimate not in player_data')
                    ...
            else:
                # print("Status code: ", player_data.status_code)
                ...
        else:
            mmr_for_players.append(None)
            # print("Player count is None, continue ...")
    if any(mmr_for_players):
        return np.mean([mmr for mmr in mmr_for_players if mmr is not None])
    return 0

# %%
"""player_id_test = 174064427
player_id_index = [player_id_test] * len(matches_for_test_player)
all_matches_df = pd.DataFrame()
columns_ = list(matches_for_test_player[0].keys())
columns_.append('player_mmr')
# columns_.append('average_match_mmr')

player_mmr = requests.get(f'{template}/players/{174064427}').json()['mmr_estimate']['estimate']
for match in matches_for_test_player:
    # calculation average mmr for each match
    # TODO refactor cause so many requests per minute (it's crashes)
    # average_match_mmr = get_average_match_mmr(match)
    
    values = list(match.values())
    values.append(player_mmr)
    # values.append(average_match_mmr)
    match_df = pd.DataFrame([values], columns=columns_, index=[player_id_test])
    all_matches_df = all_matches_df.append(match_df)
    print(f"Match {match['match_id']} has beed parsed")
# radiant_wint = all_matches_df['radiant_win'].astype(int)
# all_matches_df['radiant_win'] = radiant_wint
all_matches_df.fillna(0)"""

# %%
all_matches_df = pd.DataFrame()
columns_ = list(matches_for_test_player[0].keys())
columns_.append('player_mmr')
for player_id, matches in players_matches_dict.items():
    player_mmr = requests.get(f'{template}/players/{player_id}').json()['mmr_estimate']['estimate']
    player_id_df = player_id
    all_player_matches_df = pd.DataFrame()
    for player_match in matches:
        values = list(player_match.values())
        values.append(player_mmr)
        match_df = pd.DataFrame([values], columns=columns_, index=[player_id])
        all_player_matches_df = all_player_matches_df.append(match_df)
    all_matches_df = all_matches_df.append(all_player_matches_df)
all_matches_df
# Out:
#              match_id  player_slot  radiant_win  duration  game_mode  \
# 174064427  6281547334            4        False      2493         22
# 174064427  6281528311            1        False       961         22
# 174064427  6281499225            3        False      2013         22
# 174064427  6280039217            2        False      3453         22
# 174064427  6279998879            1         True      2323         22
# ...               ...          ...          ...       ...        ...
# 198723859  6277768373          131         True      2588         22
# 198723859  6277561378            3        False      3068         22
# 198723859  6277462984            2         True      2070         22
# 198723859  6276402485          129        False      2588         22
# 198723859  6276267611            1         True      1465         22
#
#            lobby_type  hero_id  start_time version  kills  ...  tower_damage  \
# 174064427           7       52  1637302296    None     13  ...          3310
# 174064427           7      129  1637300723    None      1  ...           965
# 174064427           7       10  1637298309    None      4  ...          2896
# 174064427           7      112  1637214839    None      5  ...           306
# 174064427           7       25  1637211477    None     10  ...          7661
# ...               ...      ...         ...     ...    ...  ...           ...
# 198723859           7       16  1637076442    None      9  ...           524
# 198723859           7      128  1637069206    None     20  ...          2941
# 198723859           7       26  1637065420    None     14  ...          1948
# 198723859           7       41  1636995313    None     17  ...          7823
# 198723859           7       19  1636990183    None      3  ...         13502
#
#            hero_healing last_hits  lane  lane_role  is_roaming  cluster  \
# 174064427             0       332  None       None        None      251
# 174064427             0        80  None       None        None      251
# 174064427             0       309  None       None        None      251
# 174064427          1784       115  None       None        None      251
# 174064427           110       269  None       None        None      251
# ...                 ...       ...   ...        ...         ...      ...
# 198723859             0       130  None       None        None      181
# 198723859             0       181  None       None        None      183
# 198723859             0        62  None       None        None      181
# 198723859             0       342  None       None        None      185
# 198723859             0       172  None       None        None      183
#
#            leaver_status  party_size player_mmr
# 174064427              0           2       3476
# 174064427              1           3       3476
# 174064427              0           3       3476
# 174064427              0           2       3476
# 174064427              0           1       3476
# ...                  ...         ...        ...
# 198723859              0           2       2227
# 198723859              0           3       2227
# 198723859              0           3       2227
# 198723859              0           1       2227
# 198723859              0           2       2227
#
# [1020 rows x 26 columns]

# %%
radiant_wint = all_matches_df['radiant_win'].astype(int)
all_matches_df['radiant_win'] = radiant_wint
all_matches_df.head()
# Out:
#              match_id  player_slot  radiant_win  duration  game_mode  \
# 174064427  6281547334            4            0      2493         22
# 174064427  6281528311            1            0       961         22
# 174064427  6281499225            3            0      2013         22
# 174064427  6280039217            2            0      3453         22
# 174064427  6279998879            1            1      2323         22
#
#            lobby_type  hero_id  start_time version  kills  ...  tower_damage  \
# 174064427           7       52  1637302296    None     13  ...          3310
# 174064427           7      129  1637300723    None      1  ...           965
# 174064427           7       10  1637298309    None      4  ...          2896
# 174064427           7      112  1637214839    None      5  ...           306
# 174064427           7       25  1637211477    None     10  ...          7661
#
#            hero_healing last_hits  lane  lane_role  is_roaming  cluster  \
# 174064427             0       332  None       None        None      251
# 174064427             0        80  None       None        None      251
# 174064427             0       309  None       None        None      251
# 174064427          1784       115  None       None        None      251
# 174064427           110       269  None       None        None      251
#
#            leaver_status  party_size player_mmr
# 174064427              0           2       3476
# 174064427              1           3       3476
# 174064427              0           3       3476
# 174064427              0           2       3476
# 174064427              0           1       3476
#
# [5 rows x 26 columns]

# %% [markdown]
# <h3>Dataframe с version, lane and lane_role

# %%
all_matches_df.to_csv('data_with_lanes.csv')

# %% [markdown]
# <h3>Cleaned data

# %%
all_matches_df.keys()
# Out:
# Index(['match_id', 'player_slot', 'radiant_win', 'duration', 'game_mode',
#        'lobby_type', 'hero_id', 'start_time', 'version', 'kills', 'deaths',
#        'assists', 'skill', 'xp_per_min', 'gold_per_min', 'hero_damage',
#        'tower_damage', 'hero_healing', 'last_hits', 'lane', 'lane_role',
#        'is_roaming', 'cluster', 'leaver_status', 'party_size', 'player_mmr'],
#       dtype='object')

# %%
columns_to_drop = ['version', 'lane', 'lane_role', 'is_roaming']

# %%
all_matches_df = all_matches_df.drop(columns_to_drop, axis = 1)

# %%
all_matches_df
# Out:
#              match_id  player_slot  radiant_win  duration  game_mode  \
# 174064427  6281547334            4            0      2493         22
# 174064427  6281528311            1            0       961         22
# 174064427  6281499225            3            0      2013         22
# 174064427  6280039217            2            0      3453         22
# 174064427  6279998879            1            1      2323         22
# ...               ...          ...          ...       ...        ...
# 198723859  6277768373          131            1      2588         22
# 198723859  6277561378            3            0      3068         22
# 198723859  6277462984            2            1      2070         22
# 198723859  6276402485          129            0      2588         22
# 198723859  6276267611            1            1      1465         22
#
#            lobby_type  hero_id  start_time  kills  deaths  ...  xp_per_min  \
# 174064427           7       52  1637302296     13      10  ...         695
# 174064427           7      129  1637300723      1       4  ...         345
# 174064427           7       10  1637298309      4       5  ...         693
# 174064427           7      112  1637214839      5      17  ...         647
# 174064427           7       25  1637211477     10      13  ...         832
# ...               ...      ...         ...    ...     ...  ...         ...
# 198723859           7       16  1637076442      9      12  ...         637
# 198723859           7      128  1637069206     20       8  ...         806
# 198723859           7       26  1637065420     14       7  ...         746
# 198723859           7       41  1636995313     17       5  ...         884
# 198723859           7       19  1636990183      3       2  ...         507
#
#           gold_per_min  hero_damage  tower_damage  hero_healing  last_hits  \
# 174064427          617        49813          3310             0        332
# 174064427          404         4465           965             0         80
# 174064427          552        16606          2896             0        309
# 174064427          400        29715           306          1784        115
# 174064427          644        33193          7661           110        269
# ...                ...          ...           ...           ...        ...
# 198723859          396        35561           524             0        130
# 198723859          531        65994          2941             0        181
# 198723859          428        21112          1948             0         62
# 198723859          673        30498          7823             0        342
# 198723859          565         7819         13502             0        172
#
#            cluster  leaver_status  party_size  player_mmr
# 174064427      251              0           2        3476
# 174064427      251              1           3        3476
# 174064427      251              0           3        3476
# 174064427      251              0           2        3476
# 174064427      251              0           1        3476
# ...            ...            ...         ...         ...
# 198723859      181              0           2        2227
# 198723859      183              0           3        2227
# 198723859      181              0           3        2227
# 198723859      185              0           1        2227
# 198723859      183              0           2        2227
#
# [1020 rows x 22 columns]

# %%
all_matches_df.to_csv('data_clean.csv')

# %%
len(set(list(all_matches_df.index)))
# Out:
# 51

# %%
all_matches_df.keys()
# Out:
# Index(['match_id', 'player_slot', 'radiant_win', 'duration', 'game_mode',
#        'lobby_type', 'hero_id', 'start_time', 'version', 'kills', 'deaths',
#        'assists', 'skill', 'xp_per_min', 'gold_per_min', 'hero_damage',
#        'tower_damage', 'hero_healing', 'last_hits', 'lane', 'lane_role',
#        'is_roaming', 'cluster', 'leaver_status', 'party_size', 'player_mmr'],
#       dtype='object')

# %%
players_matches_dict[174064427]
# Out:
# [{'match_id': 6281547334,
#   'player_slot': 4,
#   'radiant_win': False,
#   'duration': 2493,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 52,
#   'start_time': 1637302296,
#   'version': None,
#   'kills': 13,
#   'deaths': 10,
#   'assists': 8,
#   'skill': 3,
#   'xp_per_min': 695,
#   'gold_per_min': 617,
#   'hero_damage': 49813,
#   'tower_damage': 3310,
#   'hero_healing': 0,
#   'last_hits': 332,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 2},
#  {'match_id': 6281528311,
#   'player_slot': 1,
#   'radiant_win': False,
#   'duration': 961,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 129,
#   'start_time': 1637300723,
#   'version': None,
#   'kills': 1,
#   'deaths': 4,
#   'assists': 0,
#   'skill': 3,
#   'xp_per_min': 345,
#   'gold_per_min': 404,
#   'hero_damage': 4465,
#   'tower_damage': 965,
#   'hero_healing': 0,
#   'last_hits': 80,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 1,
#   'party_size': 3},
#  {'match_id': 6281499225,
#   'player_slot': 3,
#   'radiant_win': False,
#   'duration': 2013,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 10,
#   'start_time': 1637298309,
#   'version': None,
#   'kills': 4,
#   'deaths': 5,
#   'assists': 1,
#   'skill': 3,
#   'xp_per_min': 693,
#   'gold_per_min': 552,
#   'hero_damage': 16606,
#   'tower_damage': 2896,
#   'hero_healing': 0,
#   'last_hits': 309,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 3},
#  {'match_id': 6280039217,
#   'player_slot': 2,
#   'radiant_win': False,
#   'duration': 3453,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 112,
#   'start_time': 1637214839,
#   'version': None,
#   'kills': 5,
#   'deaths': 17,
#   'assists': 30,
#   'skill': 3,
#   'xp_per_min': 647,
#   'gold_per_min': 400,
#   'hero_damage': 29715,
#   'tower_damage': 306,
#   'hero_healing': 1784,
#   'last_hits': 115,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 2},
#  {'match_id': 6279998879,
#   'player_slot': 1,
#   'radiant_win': True,
#   'duration': 2323,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 25,
#   'start_time': 1637211477,
#   'version': None,
#   'kills': 10,
#   'deaths': 13,
#   'assists': 9,
#   'skill': 3,
#   'xp_per_min': 832,
#   'gold_per_min': 644,
#   'hero_damage': 33193,
#   'tower_damage': 7661,
#   'hero_healing': 110,
#   'last_hits': 269,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 1},
#  {'match_id': 6271932148,
#   'player_slot': 128,
#   'radiant_win': True,
#   'duration': 2395,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 121,
#   'start_time': 1636777295,
#   'version': None,
#   'kills': 3,
#   'deaths': 10,
#   'assists': 8,
#   'skill': 3,
#   'xp_per_min': 468,
#   'gold_per_min': 400,
#   'hero_damage': 19228,
#   'tower_damage': 589,
#   'hero_healing': 0,
#   'last_hits': 219,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6271885416,
#   'player_slot': 0,
#   'radiant_win': True,
#   'duration': 2958,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 25,
#   'start_time': 1636774018,
#   'version': None,
#   'kills': 10,
#   'deaths': 10,
#   'assists': 18,
#   'skill': 3,
#   'xp_per_min': 791,
#   'gold_per_min': 661,
#   'hero_damage': 42123,
#   'tower_damage': 16355,
#   'hero_healing': 0,
#   'last_hits': 408,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6271851560,
#   'player_slot': 128,
#   'radiant_win': True,
#   'duration': 1972,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 98,
#   'start_time': 1636771591,
#   'version': None,
#   'kills': 1,
#   'deaths': 14,
#   'assists': 5,
#   'skill': 3,
#   'xp_per_min': 363,
#   'gold_per_min': 323,
#   'hero_damage': 15192,
#   'tower_damage': 252,
#   'hero_healing': 0,
#   'last_hits': 127,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6268802962,
#   'player_slot': 129,
#   'radiant_win': True,
#   'duration': 1496,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 10,
#   'start_time': 1636609056,
#   'version': None,
#   'kills': 1,
#   'deaths': 7,
#   'assists': 5,
#   'skill': 3,
#   'xp_per_min': 504,
#   'gold_per_min': 352,
#   'hero_damage': 10737,
#   'tower_damage': 120,
#   'hero_healing': 0,
#   'last_hits': 130,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 2},
#  {'match_id': 6268543285,
#   'player_slot': 4,
#   'radiant_win': True,
#   'duration': 1982,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 120,
#   'start_time': 1636585614,
#   'version': None,
#   'kills': 4,
#   'deaths': 7,
#   'assists': 24,
#   'skill': 3,
#   'xp_per_min': 833,
#   'gold_per_min': 461,
#   'hero_damage': 14606,
#   'tower_damage': 894,
#   'hero_healing': 0,
#   'last_hits': 148,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6268509980,
#   'player_slot': 4,
#   'radiant_win': True,
#   'duration': 2530,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 135,
#   'start_time': 1636582748,
#   'version': None,
#   'kills': 12,
#   'deaths': 9,
#   'assists': 20,
#   'skill': 3,
#   'xp_per_min': 736,
#   'gold_per_min': 623,
#   'hero_damage': 36131,
#   'tower_damage': 4307,
#   'hero_healing': 7673,
#   'last_hits': 402,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6268481440,
#   'player_slot': 132,
#   'radiant_win': False,
#   'duration': 1682,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 52,
#   'start_time': 1636580652,
#   'version': None,
#   'kills': 8,
#   'deaths': 3,
#   'assists': 18,
#   'skill': 3,
#   'xp_per_min': 619,
#   'gold_per_min': 532,
#   'hero_damage': 24419,
#   'tower_damage': 10370,
#   'hero_healing': 4805,
#   'last_hits': 163,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6268445319,
#   'player_slot': 4,
#   'radiant_win': True,
#   'duration': 1898,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 98,
#   'start_time': 1636578281,
#   'version': None,
#   'kills': 8,
#   'deaths': 6,
#   'assists': 13,
#   'skill': 3,
#   'xp_per_min': 624,
#   'gold_per_min': 496,
#   'hero_damage': 24223,
#   'tower_damage': 2339,
#   'hero_healing': 0,
#   'last_hits': 144,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6268354441,
#   'player_slot': 1,
#   'radiant_win': False,
#   'duration': 1977,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 97,
#   'start_time': 1636573374,
#   'version': None,
#   'kills': 0,
#   'deaths': 11,
#   'assists': 5,
#   'skill': 3,
#   'xp_per_min': 361,
#   'gold_per_min': 301,
#   'hero_damage': 8378,
#   'tower_damage': 32,
#   'hero_healing': 0,
#   'last_hits': 109,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6268273294,
#   'player_slot': 1,
#   'radiant_win': True,
#   'duration': 3083,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 129,
#   'start_time': 1636569550,
#   'version': None,
#   'kills': 8,
#   'deaths': 13,
#   'assists': 22,
#   'skill': 3,
#   'xp_per_min': 597,
#   'gold_per_min': 499,
#   'hero_damage': 39326,
#   'tower_damage': 634,
#   'hero_healing': 0,
#   'last_hits': 272,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6265639899,
#   'player_slot': 129,
#   'radiant_win': True,
#   'duration': 2864,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 129,
#   'start_time': 1636432808,
#   'version': None,
#   'kills': 5,
#   'deaths': 12,
#   'assists': 16,
#   'skill': 3,
#   'xp_per_min': 622,
#   'gold_per_min': 489,
#   'hero_damage': 32288,
#   'tower_damage': 3287,
#   'hero_healing': 0,
#   'last_hits': 499,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6265613518,
#   'player_slot': 129,
#   'radiant_win': False,
#   'duration': 1710,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 104,
#   'start_time': 1636430733,
#   'version': None,
#   'kills': 5,
#   'deaths': 7,
#   'assists': 14,
#   'skill': 3,
#   'xp_per_min': 535,
#   'gold_per_min': 442,
#   'hero_damage': 8972,
#   'tower_damage': 4031,
#   'hero_healing': 1950,
#   'last_hits': 137,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6265575995,
#   'player_slot': 129,
#   'radiant_win': False,
#   'duration': 2688,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 97,
#   'start_time': 1636427593,
#   'version': None,
#   'kills': 4,
#   'deaths': 6,
#   'assists': 26,
#   'skill': 3,
#   'xp_per_min': 770,
#   'gold_per_min': 477,
#   'hero_damage': 13714,
#   'tower_damage': 1955,
#   'hero_healing': 0,
#   'last_hits': 234,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6257149316,
#   'player_slot': 128,
#   'radiant_win': True,
#   'duration': 3514,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 10,
#   'start_time': 1636007887,
#   'version': None,
#   'kills': 13,
#   'deaths': 4,
#   'assists': 7,
#   'skill': 3,
#   'xp_per_min': 787,
#   'gold_per_min': 758,
#   'hero_damage': 64872,
#   'tower_damage': 8676,
#   'hero_healing': 0,
#   'last_hits': 668,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5},
#  {'match_id': 6257119179,
#   'player_slot': 0,
#   'radiant_win': True,
#   'duration': 1961,
#   'game_mode': 22,
#   'lobby_type': 7,
#   'hero_id': 10,
#   'start_time': 1636005597,
#   'version': None,
#   'kills': 11,
#   'deaths': 3,
#   'assists': 6,
#   'skill': 3,
#   'xp_per_min': 895,
#   'gold_per_min': 705,
#   'hero_damage': 24469,
#   'tower_damage': 15648,
#   'hero_healing': 0,
#   'last_hits': 325,
#   'lane': None,
#   'lane_role': None,
#   'is_roaming': None,
#   'cluster': 251,
#   'leaver_status': 0,
#   'party_size': 5}]

# %% [markdown]
# <h2>Inserting rows to pandas dataframe

# %%
columns_for_df = list(players_matches_dict[174064427][0].keys())
columns_for_df[:5]
# Out:
# ['match_id', 'player_slot', 'radiant_win', 'duration', 'game_mode']

# %%
test_data = {'match_id': 6281528311, 'player_slot': 1}

# %%
df = pd.DataFrame(players_matches_dict[174064427][0], index=['match_id'])

# %%
df
# Out:
#             match_id  player_slot  radiant_win  duration  game_mode  \
# match_id  6281528311            1        False       961         22
#
#           lobby_type  hero_id  start_time version  kills  ...  hero_damage  \
# match_id           7      129  1637300723    None      1  ...         4465
#
#           tower_damage  hero_healing  last_hits  lane  lane_role  is_roaming  \
# match_id           965             0         80  None       None        None
#
#           cluster  leaver_status party_size
# match_id      251              1          3
#
# [1 rows x 25 columns]

# %%
type(match)
# Out:
# requests.models.Response

# %%
isinstance(match, requests.Response)
# Out:
# True

# %%
resp = requests.get(f'{template}/players/{124101446}/recentMatches')
resp.status_code
# Out:
# 200

# %%
resp.json()[0]
# Out:
# {'match_id': 6281507718,
#  'player_slot': 128,
#  'radiant_win': True,
#  'duration': 820,
#  'game_mode': 3,
#  'lobby_type': 7,
#  'hero_id': 81,
#  'start_time': 1637299010,
#  'version': None,
#  'kills': 0,
#  'deaths': 3,
#  'assists': 2,
#  'skill': 2,
#  'xp_per_min': 279,
#  'gold_per_min': 294,
#  'hero_damage': 3047,
#  'tower_damage': 0,
#  'hero_healing': 0,
#  'last_hits': 45,
#  'lane': None,
#  'lane_role': None,
#  'is_roaming': None,
#  'cluster': 227,
#  'leaver_status': 1,
#  'party_size': 1}

# %%
len([match['avg_mmr'] for match in public_matches.json() if match['avg_mmr'] is not None])
# Out:
# 75

# %%
match = requests.get(f'{template}/matches/6281490919')
match.status_code
# Out:
# 200

# %%
match.json()['skill']
# Out:
# 3

# %%
player_matches = requests.get(f'{template}/players/{124101446}/matches?limit=10')
player_matches.status_code
# Out:
# 200

# %%
player_matches.json()[0]
# Out:
# {'match_id': 6281507718,
#  'player_slot': 128,
#  'radiant_win': True,
#  'duration': 820,
#  'game_mode': 3,
#  'lobby_type': 7,
#  'hero_id': 81,
#  'start_time': 1637299010,
#  'version': None,
#  'kills': 0,
#  'deaths': 3,
#  'assists': 2,
#  'skill': 2,
#  'leaver_status': 1,
#  'party_size': 1}

# %%
match = requests.get(f'{template}/matches/6281507718')

# %%
[match['account_id'] for match in match.json()['players']]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  124101446,
#  915891389,
#  169100142,
#  185574063,
#  256317901]

# %%
[datetime.fromtimestamp(match['start_time']).date() for match in player_matches.json()]
# Out:
# [datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 19),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 18),
#  datetime.date(2021, 11, 13),
#  datetime.date(2021, 11, 13),
#  datetime.date(2021, 11, 13),
#  datetime.date(2021, 11, 13),
#  datetime.date(2021, 11, 13)]

# %% [markdown]
# <h2>There is not prof matches for ordinary players, so, rows object will be empty

# %%
response_explorer = requests.get(f"https://api.opendota.com/api/explorer?sql=SELECT match_id FROM player_matches WHERE player_matches.account_id = 124101446 LIMIT 10")
response_explorer.status_code
# Out:
# 200

# %%
response_explorer.json()['rows']
# Out:
# []
